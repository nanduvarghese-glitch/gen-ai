# %% [markdown]
# <a href="https://colab.research.google.com/github/nanduvarghese-glitch/gen-ai/blob/main/preprocessing_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import sklearn.preprocessing

# %%
df=pd.read_csv('/content/preprocessing_practice_dataset.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Employee_ID         100 non-null    int64
#  1   Age                 90 non-null     float64
#  2   Gender              100 non-null    object
#  3   Department          90 non-null     object
#  4   Education           90 non-null     object
#  5   Experience_Years    100 non-null    int64
#  6   Monthly_Salary      90 non-null     float64
#  7   Performance_Rating  100 non-null    int64
#  8   City                90 non-null     object
#  9   Attrition           100 non-null    object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 7.9+ KB

# %%
encoder=df.copy()

# %%
df.isnull()
# Out:
#     Employee_ID    Age  Gender  Department  Education  Experience_Years  \
# 0         False  False   False       False      False             False
# 1         False  False   False       False      False             False
# 2         False  False   False       False       True             False
# 3         False  False   False       False      False             False
# 4         False  False   False       False      False             False
# ..          ...    ...     ...         ...        ...               ...
# 95        False  False   False       False      False             False
# 96        False  False   False       False      False             False
# 97        False  False   False        True      False             False
# 98        False  False   False       False      False             False
# 99        False  False   False        True       True             False
#
#     Monthly_Salary  Performance_Rating   City  Attrition
# ...

# %%
df.isnull().sum()
# Out:
# Employee_ID            0
# Age                   10
# Gender                 0
# Department            10
# Education             10
# Experience_Years       0
# Monthly_Salary        10
# Performance_Rating     0
# City                  10
# Attrition              0
# dtype: int64

# %%
df['Age_mean_imputed'] = df['Age'].fillna(df['Age'].mean())

# %%
df['Age_median_imputed'] = df['Age'].fillna(df['Age'].median())

# %%
df['City_mode_imputed'] = df['City'].fillna(df['City'].mode()[0])

# %%
df[["Age","Age_mean_imputed","Age_median_imputed"]]
# Out:
#      Age  Age_mean_imputed  Age_median_imputed
# 0   59.0              59.0                59.0
# 1   49.0              49.0                49.0
# 2   35.0              35.0                35.0
# 3   28.0              28.0                28.0
# 4   41.0              41.0                41.0
# ..   ...               ...                 ...
# 95  54.0              54.0                54.0
# 96  53.0              53.0                53.0
# 97  43.0              43.0                43.0
# 98  44.0              44.0                44.0
# 99  57.0              57.0                57.0
#
# [100 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# %%
sns.set(style="whitegrid")

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='Experience_Years', y='Performance_Rating',palette='pastel')
plt.title('Bar Plot of Performance Rating by Experience', fontsize=16)
plt.xlabel('Experience_Years',fontsize=12)
plt.ylabel('Performance_Rating',fontsize=12)
# Out:
# /tmp/ipykernel_4946/430976232.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='Experience_Years', y='Performance_Rating',palette='pastel')
# Text(0, 0.5, 'Performance_Rating')

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Experience_Years', y='Performance_Rating',palette='pastel')
plt.title('Box Plot of Performance Rating by Experience', fontsize=16)
plt.xlabel('Experience_Years',fontsize=12)
plt.ylabel('Performance_Rating',fontsize=12)
# Out:
# /tmp/ipykernel_4946/2979172978.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Experience_Years', y='Performance_Rating',palette='pastel')
# Text(0, 0.5, 'Performance_Rating')

# %%
plt.figure(figsize=(10, 6))
# Seaborn does not have a 'pieplot' function. Use matplotlib.pyplot.pie.
# For a pie chart, we typically plot the distribution of a single categorical variable.
# Let's plot the distribution of 'Performance_Rating'.
rating_counts = df['Performance_Rating'].value_counts()
plt.pie(rating_counts, labels=rating_counts.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette('muted'))
plt.title('Distribution of Performance Rating', fontsize=16)
# x and y labels are not typically used for pie charts.
plt.xlabel('')
plt.ylabel('')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x='Experience_Years', y='Performance_Rating',palette='muted')
plt.title('line Plot of Performance Rating by Experience', fontsize=16)
plt.xlabel('Experience_Years',fontsize=12)
plt.ylabel('Performance_Rating',fontsize=12)
# Out:
# /tmp/ipykernel_4946/2037252345.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=df, x='Experience_Years', y='Performance_Rating',palette='muted')
# Text(0, 0.5, 'Performance_Rating')

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Experience_Years', y='Performance_Rating',palette='pastel')
plt.title('Bar Plot of Performance Rating by Experience', fontsize=16)
plt.xlabel('Experience_Years',fontsize=12)
plt.ylabel('Performance_Rating',fontsize=12)
# Out:
# /tmp/ipykernel_4946/3813078091.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=df, x='Experience_Years', y='Performance_Rating',palette='pastel')
# Text(0, 0.5, 'Performance_Rating')

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Experience_Years', y='Performance_Rating',palette='set3')
plt.title('Bar Plot of Performance Rating by Experience', fontsize=16)
plt.xlabel('Experience_Years',fontsize=12)
plt.ylabel('Performance_Rating',fontsize=12)
# Out:
# /tmp/ipykernel_4946/213550186.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=df, x='Experience_Years', y='Performance_Rating',palette='set3')
# Text(0, 0.5, 'Performance_Rating')

# %%
encoded_data = df.copy()
one_hot_encoded = pd.get_dummies(encoded_data['Attrition'], prefix='Attrition')
encoded_data = pd.concat([encoded_data, one_hot_encoded], axis=1)
perfomance_rating_mapping = {1: 'First', 2: 'Second', 3: 'Third',4:'Fourth',5:'Fifth'}
encoded_data['Performance_Rating_Category'] = encoded_data['Performance_Rating'].map(perfomance_rating_mapping)
print(encoded_data[[ 'Age','Attrition' ,'Attrition_Yes',  'Attrition_No', 'Performance_Rating', 'Performance_Rating_Category']].head())
# Out:
#     Age Attrition  Attrition_Yes  Attrition_No  Performance_Rating  \
# 0  59.0        No          False          True                   5
# 1  49.0       Yes           True         False                   2
# 2  35.0       Yes           True         False                   1
# 3  28.0       Yes           True         False                   2
# 4  41.0       Yes           True         False                   3
#
#   Performance_Rating_Category
# 0                       Fifth
# 1                      Second
# 2                       First
# 3                      Second
# 4                       Third

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

# %%
file_path='/content/preprocessing_practice_dataset.csv'
titanic_data=pd.read_csv(file_path)

# %%
numerical_columns=['Age','Department','Perfomance_Rating']

# %%
df=pd.read_csv('/content/preprocessing_practice_dataset.csv')

# %%
numerical_columns=['Age','Performance_Rating']
df.dropna(subset=numerical_columns,inplace=True)

# %%
minmax_scaler=MinMaxScaler()
standard_scaler=StandardScaler()
robust_scaler=RobustScaler()

# %%
df['Age_MinMax']=minmax_scaler.fit_transform(df[['Age']])
df['Performance_Rating_MinMax']=minmax_scaler.fit_transform(df[['Performance_Rating']])

# %%
titanic_data['Age_Standard']=standard_scaler.fit_transform(titanic_data[['Age']])
titanic_data['Performance_Rating_Standard']=standard_scaler.fit_transform(titanic_data[['Performance_Rating']])

# %%
titanic_data['Age_Robust']=robust_scaler.fit_transform(titanic_data[['Age']])
titanic_data['Perfoemance_Rating_Robust']=robust_scaler.fit_transform(titanic_data[['Performance_Rating']])

# %%
titanic_data[['Age','Age_MinMax','Age_Standard','Age_Robust']]
# Out:
#      Age  Age_MinMax  Age_Standard  Age_Robust
# 0   59.0    1.000000      1.746756    0.960000
# 1   49.0    0.736842      0.833817    0.426667
# 2   35.0    0.368421     -0.444297   -0.320000
# 3   28.0    0.184211     -1.083354   -0.693333
# 4   41.0    0.526316      0.103466    0.000000
# ..   ...         ...           ...         ...
# 95  54.0    0.868421      1.290286    0.693333
# 96  53.0    0.842105      1.198993    0.640000
# 97  43.0    0.578947      0.286054    0.106667
# 98  44.0    0.605263      0.377348    0.160000
# 99  57.0    0.947368      1.564168    0.853333
#
# [100 rows x 4 columns]
